# %%
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
# %matplotlib inline

from matplotlib.font_manager import FontProperties
params = {'font.family': 'serif',}
matplotlib.rcParams.update(params)

from scipy.io import readsav

# %%
path='/Users/ermay/Documents/GradSchool/Research_Surface/GCM_plots/Files/FiducialPlanet/VarTdiss/'

td_001_waveno=readsav(path+'/td_001/kespec.sav')['twaveno']
td_001_itke=readsav(path+'/td_001/kespec.sav')['itke']

td_005_waveno=readsav(path+'/td_005/kespec.sav')['twaveno']
td_005_itke=readsav(path+'/td_005/kespec.sav')['itke']

td_010_waveno=readsav(path+'/td_010/kespec.sav')['twaveno']
td_010_itke=readsav(path+'/td_010/kespec.sav')['itke']

td_015_waveno=readsav(path+'/td_015/kespec.sav')['twaveno']
td_015_itke=readsav(path+'/td_015/kespec.sav')['itke']

td_020_waveno=readsav(path+'/td_020/kespec.sav')['twaveno']
td_020_itke=readsav(path+'/td_020/kespec.sav')['itke']

td_025_waveno=readsav(path+'/td_025/kespec.sav')['twaveno']
td_025_itke=readsav(path+'/td_025/kespec.sav')['itke']

td_030_waveno=readsav(path+'/td_030/kespec.sav')['twaveno']
td_030_itke=readsav(path+'/td_030/kespec.sav')['itke']

td_050_waveno=readsav(path+'/td_050/kespec.sav')['twaveno']
td_050_itke=readsav(path+'/td_050/kespec.sav')['itke']

td_070_waveno=readsav(path+'/td_070/kespec.sav')['twaveno']
td_070_itke=readsav(path+'/td_070/kespec.sav')['itke']

td_100_waveno=readsav(path+'/td_100/kespec.sav')['twaveno']
td_100_itke=readsav(path+'/td_100/kespec.sav')['itke']

td_150_waveno=readsav(path+'/td_150/kespec.sav')['twaveno']
td_150_itke=readsav(path+'/td_150/kespec.sav')['itke']

td_200_waveno=readsav(path+'/td_200/kespec.sav')['twaveno']
td_200_itke=readsav(path+'/td_200/kespec.sav')['itke']

# %%
plt.figure(figsize=(8.5,7))
plt.gcf().subplots_adjust(bottom=0.12,top=0.95,left=0.15,right=0.99)

a=4
colors1 = plt.cm.viridis(np.linspace(0, 1, a*12+a))

plt.plot(td_001_waveno,td_001_itke,linestyle='--',linewidth=1.5,label='0.001',color=colors1[a*1])
plt.plot(td_005_waveno,td_005_itke,linestyle='-', linewidth=3.0,label='0.005',color=colors1[a*2],zorder=50)
plt.plot(td_010_waveno,td_010_itke,linestyle='--',linewidth=1.5,label='0.010',color=colors1[a*3])
plt.plot(td_015_waveno,td_015_itke,linestyle='--',linewidth=1.5,label='0.015',color=colors1[a*4])
plt.plot(td_020_waveno,td_020_itke,linestyle='--',linewidth=1.5,label='0.020',color=colors1[a*5])
plt.plot(td_025_waveno,td_025_itke,linestyle='--',linewidth=1.5,label='0.025',color=colors1[a*6])
plt.plot(td_030_waveno,td_030_itke,linestyle='--',linewidth=1.5,label='0.030',color=colors1[a*7])
plt.plot(td_050_waveno,td_070_itke,linestyle='--',linewidth=1.5,label='0.050',color=colors1[a*8])
plt.plot(td_050_waveno,td_070_itke,linestyle='--',linewidth=1.5,label='0.070',color=colors1[a*9])
plt.plot(td_100_waveno,td_100_itke,linestyle='--',linewidth=1.5,label='0.100',color=colors1[a*10])
plt.plot(td_150_waveno,td_150_itke,linestyle='--',linewidth=1.5,label='0.150',color=colors1[a*11])
plt.plot(td_200_waveno,td_200_itke,linestyle='--',linewidth=1.5,label='0.200',color=colors1[a*12])

#plt.figtext(0.48,0.37,'Mini-Neptune Dissipation Params',fontsize=20,fontweight='bold',ha='center')
#plt.legend(loc='lower left',fontsize=18,frameon=False,markerscale=1.5,ncol=3)

plt.yscale('log')
plt.yticks(fontsize=18)
plt.ylabel('Kinetic Energy [J/m$^2$]',fontsize=25)

plt.xscale('log')
plt.xticks(fontsize=15)
plt.xlabel('Total Wavenumber',fontsize=25)

plt.ylim(10**-4,10**2.)

#plt.savefig(path+'kespec.pdf')
# Out:
# (0.0001, 100.0)
