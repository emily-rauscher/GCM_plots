# %%
from SurfacePressure_func import SurfPress
# %matplotlib inline

path='/Users/ermay/Documents/GradSchool/Research_Surface/GCM_Plots/Files/'
runname='FiducialPlanet_NEW/Model3/P0_075'
#runname='FiducialPlanet/Model3/L30/P0_075'
makeplot=True
saveplot=True

data_50=SurfPress(path,runname,0,0.1,makeplot, saveplot,path+runname+'/SurfP.png')
# Out:
#
#  ....reading fort.50
#        nlat= 64 nlon= 128
#        END OF FILE: DONE
# (8192, 3)
# (128, 64, 3)
