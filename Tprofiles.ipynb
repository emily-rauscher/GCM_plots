# %%
from load_data_noin import load_data

path='/Users/hbeltz/Documents/runs/'
runname='test03'
oom=7
surfp=100
LastOrbit_=False
OLR_=False
verbose=False
fort_file= 'fort.2615'
fort_64='fort.6415'
rotate=True
prot=3.525
porb=3.525
caption=False

runname,lon_arr,lat_arr,oom,surfp,p_BAR,data_26,data_lo,data_olr=load_data(path,runname,oom,
                                                                           surfp,LastOrbit_,OLR_,verbose,fort_file,fort_64,rotate,prot,porb,caption)
# Out:
#
#  ....reading  fort.2615
#        nlat= 48 nlon= 96 nlev= 45
#        END OF FILE: DONE

# %%
from tprof import tprof
#reads in fort.50 
nlay=45     #number of layers

savefig=True
path='/Users/hbeltz/Documents/runs/'
runname='test03'
savename=path+runname+'/'+runname+'tprofnewfinal'+'.png'


# %matplotlib inline
tprof(lon_arr,lat_arr,p_BAR,data_26,oom,surfp,nlay,runname,path,
         savefig,savename)
# Out:
# info coming!
# 1.2385370631280586e-05
# 1.1961283330787515e-05
# 1.2289560751800976e-05
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
