# %%
from SurfacePressure_func import SurfPress
# %matplotlib inline

path='/Users/ermay/Documents/GradSchool/Research_Surface/GCM_Plots/Files/'
runname='FiducialPlanet/Model4_0'
makeplot=True
saveplot=True

data_50=SurfPress(path,runname,0,0.1,makeplot, saveplot,path+runname+'Model4_SurfP.png')
# Out:
#
#  ....reading fort.50
#        nlat= 64 nlon= 128
#        END OF FILE: DONE
# (8192, 3)
# (128, 64, 3)
