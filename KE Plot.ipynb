# %%
from makekeplot import KEplot

path='/Users/hbeltz/Documents/GCM_plots-master/'
runname='test02'#name of the folder with the run
lay=45
minV=50 #setting the color bar mins and max
maxV=65
savename=path+runname+'/'+runname+'KE'+'.png'
# %matplotlib inline
KEplot(path,runname,lay,savename,minV,maxV)
# Out:
# Pressure OOM?:7
# Surface Press [bar]:100
# Number of days:1000

# %%
# Out:
# you called the function you funky little astronomer
