# %%
from KEdiag_func import KEplot

#path='/Users/hbeltz/Documents/runs/'
#runname='crun2'#name of the folder with the run
path='/Users/ermay/Documents/GradSchool/Research_Surface/GCM_plots/Files/'
runname='FiducialPlanet/Model4/L10/T42/P0_020/'#Model4/Test_New/'#/L10/T42/P0_050'

oom=0
press=0.2
ndays=2000
lay=10 #number of total layers in the run

minV=0 #setting the color bar mins and max (remember this is log scale)
maxV=0
savename=path+runname+'/KE.png'
# %matplotlib inline
KEplot(path,runname,oom,press,ndays,lay,savename,minV,maxV)

# %%
from scipy.io import FortranFile
import numpy as np

path='/Users/ermay/Documents/GradSchool/Research_Surface/GCM_plots/Files/'
filename='FiducialPlanet/Model4/L10/T42/P0_020'

f=FortranFile(path+filename+'/fort.52','r')
print f
f.read_reals()
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-b876eb63462d> in <module>()
#       7 f=FortranFile(path+filename+'/fort.52','r')
#       8 print f
# ----> 9 f.read_reals()
#
# /usr/local/anaconda/lib/python2.7/site-packages/scipy/io/_fortran.pyc in read_reals(self, dtype)
#     300
#     301         """
# --> 302         return self.read_record(dtype)
#     303
#     304     def close(self):
#
# /usr/local/anaconda/lib/python2.7/site-packages/scipy/io/_fortran.pyc in read_record(self, *dtypes, **kwargs)
#     245             data.append(r)
#     246
# --> 247         second_size = self._read_size()
#     248         if first_size != second_size:
#     249             raise IOError('Sizes do not agree in the header and footer for '
#
# /usr/local/anaconda/lib/python2.7/site-packages/scipy/io/_fortran.pyc in _read_size(self)
#     107
# ...

# %%
# nlat= 64 nlon= 128 nlev= 10
#print float(test.shape[0])
print 10.*2090.
# Out:
# 70571.0
# 40020.0

# %%
print 10.*2091.
# Out:
# 20910.0
