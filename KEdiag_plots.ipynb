# %%
from KEdiag_func import KEplot

path='/Users/hbeltz/Documents/runs/'
runname='crun2'#name of the folder with the run
lay=45 #number of total layers in the run
minV=50 #setting the color bar mins and max (remember this is log scale)
maxV=65
savename=path+runname+'/'+runname+'KE'+'.png'
# %matplotlib inline
KEplot(path,runname,lay,savename,minV,maxV)
# Out:
# Pressure OOM?:7
# Surface Press [bar]:100
# Number of days:633

# %%
print (lay)
# Out:
# 45
